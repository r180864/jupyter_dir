# %% [markdown]
# # Store Excel Details in Database

# %%
import pymysql

# %%
server=pymysql.connect(host='localhost', user='root', passwd='Getin@2001', db='Results')
server.autocommit(True)

# %%
cursor=server.cursor()

# %%
sql="CREATE TABLE IF NOT EXISTS marks(id CHAR(7), name VARCHAR(50), ac_year CHAR(9), branch CHAR(5), year CHAR(6), sem CHAR(5), code CHAR(8), subject VARCHAR(30), credits INT, wat1 INT, wat2 INT, bow INT, mid1 INT, mid2 INT, mid3 INT, bom INT, internal INT, grade VARCHAR(3), yop VARCHAR(15), batch CHAR(3), gp INT);"
cursor.execute(sql)
# Out:
# 0

# %%
import pandas as pd

# %%
data=pd.read_excel('AY2022-23_R18 Batch_E3S1_RESULTS_Form-F.xlsx')

# %%
data.head()
# Out:
#     Reg.Id                        Name         AY BRANCH    YEAR Semester  \
# 0  O180585   SOMANDEPALLI SAI CHETHANA  AY2022-23     EC  Engg-3    SEM-1
# 1  O180889                   K LAKSHMI  AY2022-23     EC  Engg-3    SEM-1
# 2  N180967                   S PADMAJA  AY2022-23     EC  Engg-3    SEM-1
# 3  S180945  YERRAPAPIGARI RENUKA PRIYA  AY2022-23     EC  Engg-3    SEM-1
# 4  S180137       KUNTIMALLA PRATHYUSHA  AY2022-23     EC  Engg-3    SEM-1
#
#   Course\nCode       Subject Name  SUBJECT\nCREDITS AT-1\n(10) AT-2\n(10)  \
# 0     20EC3102  Computer Networks               3.0         10          8
# 1     20EC3102  Computer Networks               3.0         10          4
# 2     20EC3102  Computer Networks               3.0          9          6
# 3     20EC3102  Computer Networks               3.0         10          3
# 4     20EC3102  Computer Networks               3.0          6          8
#
#   ATs\nBO1\n(10) MID-1\n(15) MID-2\n(15) MID-3\n(15)  \
# ...

# %%
df=pd.DataFrame(data)

# %%
df.columns=['id', 'name', 'ay', 'branch', 'year', 'semester', 'code', 'subject', 'credits', 'wat1', 'wat2', 'bow', 'mid1', 'mid2', 'mid3', 'bom', 'internal', 'grade', 'yop', 'batch']

# %%
df.columns, len(df.columns)
# Out:
# (Index(['id', 'name', 'ay', 'branch', 'year', 'semester', 'code', 'subject',
#         'credits', 'wat1', 'wat2', 'bow', 'mid1', 'mid2', 'mid3', 'bom',
#         'internal', 'grade', 'yop', 'batch'],
#        dtype='object'),
#  20)

# %%
#For Non CSE
for i in range(0, 9672):
    if(df['branch'][i]=="CS"):
        continue
    if(type(df['mid1'][i]) is not int):
        df['mid1'][i]=0
    if(type(df['mid2'][i]) is not int):
        df['mid2'][i]=0
    if(type(df['mid3'][i]) is not int):
        df['mid3'][i]=0
    if(type(df['bom'][i]) is not int):
        df['bom'][i]=0
        
    if(type(df['wat1'][i]) is not int):
        df['wat1'][i]=0
    if(type(df['wat2'][i]) is not int):
        df['wat2'][i]=0
    if(type(df['bow'][i]) is not int):
        df['bow'][i]=0
        
    if(type(df['internal'][i]) is not int):
        df['internal'][i]=0
    grade=df['grade'][i]
    
    if(grade=='Ex'):
        points=10
    elif(grade=='A'):
        points=9
    elif(grade=='B'):
        points=8
    elif(grade=='C'):
        points=7
    elif(grade=='D'):
        points=6
    elif(grade=='E'):
        points=5
    elif(grade=='R'):
        points=0
    elif(grade=='AB'):
        points=0
    elif(grade=='MP'):
        points=0
    else:
        points=0
    sql="INSERT INTO marks VALUES('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', {}, {}, {}, {}, {}, {}, {}, {}, {}, '{}', '{}', '{}', {});".format(df['id'][i], df['name'][i], df['ay'][i], df['branch'][i], df['year'][i], df['semester'][i], df['code'][i], df['subject'][i], df['credits'][i], df['wat1'][i], df['wat2'][i], df['bow'][i], df['mid1'][i], df['mid2'][i], df['mid2'][i], df['bom'][i], df['internal'][i], df['grade'][i], df['yop'][i], df['batch'][i], points)
    cursor.execute(sql)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7380\945371937.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mid2'][i]=0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7380\945371937.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mid3'][i]=0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7380\945371937.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mid1'][i]=0
# ...

# %%
#For CSE
df=data=pd.read_excel('CSE_FORM F.xlsx')
df=pd.DataFrame(data)
df.columns=['id', 'name', 'ay', 'branch', 'year', 'semester', 'code', 'subject', 'credits', 'wat1', 'wat2', 'bow', 'mid1', 'mid2', 'mid3', 'bom', 'internal', 'grade', 'yop', 'batch']

for i in range(0, 2895):
    if(df['branch'][i]!="CS"):
        continue
    if(type(df['mid1'][i]) is not int):
        df['mid1'][i]=0
    if(type(df['mid2'][i]) is not int):
        df['mid2'][i]=0
    if(type(df['mid3'][i]) is not int):
        df['mid3'][i]=0
    if(type(df['bom'][i]) is not int):
        df['bom'][i]=0
        
    if(type(df['wat1'][i]) is not int):
        df['wat1'][i]=0
    if(type(df['wat2'][i]) is not int):
        df['wat2'][i]=0
    if(type(df['bow'][i]) is not int):
        df['bow'][i]=0
        
    if(type(df['internal'][i]) is not int):
        df['internal'][i]=0
    grade=df['grade'][i]
    
    if(grade=='Ex'):
        points=10
    elif(grade=='A'):
        points=9
    elif(grade=='B'):
        points=8
    elif(grade=='C'):
        points=7
    elif(grade=='D'):
        points=6
    elif(grade=='E'):
        points=5
    elif(grade=='R'):
        points=0
    elif(grade=='AB'):
        points=0
    elif(grade=='MP'):
        points=0
    else:
        points=0
    sql="INSERT INTO marks VALUES('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', {}, {}, {}, {}, {}, {}, {}, {}, {}, '{}', '{}', '{}', {});".format(df['id'][i], df['name'][i], df['ay'][i], df['branch'][i], df['year'][i], df['semester'][i], df['code'][i], df['subject'][i], df['credits'][i], df['wat1'][i], df['wat2'][i], df['bow'][i], df['mid1'][i], df['mid2'][i], df['mid2'][i], df['bom'][i], df['internal'][i], df['grade'][i], df['yop'][i], df['batch'][i], points)
    cursor.execute(sql)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7380\703126266.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wat1'][i]=0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7380\703126266.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mid3'][i]=0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7380\703126266.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mid1'][i]=0
# ...

# %%
sql
# Out:
# 'SELECT * FROM marks;'

# %%
sql='SELECT * FROM marks;'
cursor.execute(sql)
# Out:
# 9671

# %%
pd.DataFrame(cursor.fetchall(), columns=['id', 'name', 'ay', 'branch', 'year', 'semester', 'code', 'subject', 'credits', 'wat1', 'wat2', 'bow', 'mid1', 'mid2', 'mid3', 'bom', 'internal', 'grade', 'yop', 'batch', 'points'])
# Out:
#            id                        name         ay branch    year semester  \
# 0     O180585   SOMANDEPALLI SAI CHETHANA  AY2022-23     EC  Engg-3    SEM-1
# 1     O180889                   K LAKSHMI  AY2022-23     EC  Engg-3    SEM-1
# 2     N180967                   S PADMAJA  AY2022-23     EC  Engg-3    SEM-1
# 3     S180945  YERRAPAPIGARI RENUKA PRIYA  AY2022-23     EC  Engg-3    SEM-1
# 4     S180137       KUNTIMALLA PRATHYUSHA  AY2022-23     EC  Engg-3    SEM-1
# ...       ...                         ...        ...    ...     ...      ...
# 9666  R180029       PITHAVATH PALVANI BAI  AY2022-23     CS  Engg-3    SEM-1
# 9667  R180061                 DANDE VAMSI  AY2022-23     CS  Engg-3    SEM-1
# 9668  R180733          MIDDE SANJAY KUMAR  AY2022-23     CS  Engg-3    SEM-1
# 9669  R180211     PERNAPATI NAVYA LAKSHMI  AY2022-23     CS  Engg-3    SEM-1
# 9670  R180753            REVANTH D RAMPAL  AY2022-23     CS  Engg-3    SEM-1
#
# ...

# %%
sql='SELECT DISTINCT grade from marks'
cursor.execute(sql)
# Out:
# 10

# %%
cursor.fetchall()
# Out:
# (('E',),
#  ('A',),
#  ('B',),
#  ('R',),
#  ('AB',),
#  ('Ex',),
#  ('D',),
#  ('C',),
#  ('MP',),
#  ('P',))

# %%
sql='ALTER TABLE marks add column gp INT'
cursor.execute(sql)
